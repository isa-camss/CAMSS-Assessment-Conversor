# %% [markdown]
# # <center>CAMSS Utilities</center>
# ## <center>Migration of the CAMSS Assessment, from the previous releases of the CAMSS Assessment EIF Scenario to the latest CAMSS Assessment EIF Scenario version 5.1.0</center>
# ### <center>Compatible with EIF(v300), EIF(v310) and EIF(v500) CAMSS Assessment EIF Scenario Solutions</center>
# <center><img src="./img/CAMSS Logo landscape"/></center>
# <center>European Commission, Digital Europe Programme (DIGITAL), DIGIT</center>
# <center><a href="mailto:camss@everis.com">camss@everis.nttdata.com</a></center>
# <center><a href="https://joinup.ec.europa.eu/collection/eupl/about">UPL Licence</a><center>
# <center>Build 20221031T18:00</center>
# <center>Version 1.0</center>

# %%
#    Notice: If you want to hide the code cells, please run this cell.
#    If you are interested in checking the code, access the file hidecode.py in the project folder.

from utils import display_hidebuttom
display_hidebuttom()
# Out:
# <script>$("div.input").hide()</script>
# ToggleButton(value=False, description='Show code')
# <script>$("div.input").show()</script>

# %% [markdown]
# <h2>How can I use this notebook?</h2><br>
# Place the cursor in this cell, and click on the Run buttom (in the notebook's above bar) cell by cell.<br>

# %% [markdown]
# <h2>What does the notebook do?</h2><br>
#
# <div>This <b>Assessment Conversor</b> -a CAMSS Utilities notebook- is a module that receives an RDF in <a href="https://joinup.ec.europa.eu/collection/common-assessment-method-standards-and-specifications-camss/solution/camss-tools/release/v300">CAMSS EIF scenario 3.0.0</a> (deprecated CAMSS Tools), <a href="https://joinup.ec.europa.eu/collection/common-assessment-method-standards-and-specifications-camss/solution/camss-tools/release/v400">CAMSS EIF scenario 3.1.0</a> (deprecated CAMSS Tools), <a href="https://joinup.ec.europa.eu/collection/common-assessment-method-standards-and-specifications-camss/solution/camss-assessment-eif-scenario/release/v500">CAMSS EIF scenario 5.0.0</a> (CAMSS Solution former version) and transforms them into the latest version <a href="https://joinup.ec.europa.eu/collection/common-assessment-method-standards-and-specifications-camss/solution/camss-assessment-eif-scenario/release/v510">CAMSS EIF scenario 5.1.0</a> of the CAMSS EIF scenario.<br>
#
#
# <h3>How do RDF files look like?</h3><br>
#     RDF files are labelled distinctively depending on the CAMSS EIF scenario version, see examples below:<br>         <br><center>EIF-3.1.0-EIF-3.1.0-CAMSS Assessment ODLR 2.2_EIF Scenario_v1.0.0.ttl</center><br><center><center>EIF-3.0.0-EIF-3.0.0-CAMSS Assessment of XSD 1.1v.1.0.0.ttl</center><br></center><br><center>EIF-3.1.0-EIF-3.1.0-CAMSS Assessment - Standard for Public Code v1.ttl</center><br>        Assessments RDF file names are referred to by three digits, by the version of the assessment (usually three digits at the end of the file name), and the naming of the specification, which optionally includes its version.<br>
#
# <h3>And then?</h3><br>
#     It is an automated conversor designed to convert any CAMSS Assessment EIF Scenario files in RDF format.<br><br>
# Once the CAMSS Assessments are processed, RDF files are stored locally in the user's machine in the 'out' folder (inside the project folder) as an RDF file containing all the assessments. This file it is said to contain the CAMSS Assessments graph, ready to be shared in CELLAR TripleStore. Additionally, in 'out', in their respective subfolders, individual RDF files of the individual converted assessments are also delivered.<br><br>
# </div><br>

# %%
import migration as camss

# %% [markdown]
# ---

# %% [markdown]
# ## CAMSS Assessments migration to CAMSS EIF scenario v5.1.0

# %% [markdown]
# A) Assessments RDF files are placed in the 'in' folder. This notebook gets inside the 'in' folder and processes all these files.<br><br>

# %% [markdown]
# B) Mind the 'AssessnentsG' folder, which only have to contain the last update of the Assessments graph.<br><br>

# %% [markdown]
# C) Follow the progress of the Assessments Migration Tool:

# %%
camss.run()
# Out:
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_SAMM_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment_RDF_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_RegOrg_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the SAMM CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the RDF CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the RegOrg CAMSS Assessment EIF 3.1.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_OWL2_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS_Assessment_HTTPS_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment_DNS_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the OWL2 CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the HTTPS CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the DNS CAMSS Assessment EIF 3.0.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_ADMS_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment_FTP_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_CCCEV_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the ADMS CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the FTP CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the CCCEV CAMSS Assessment EIF 3.1.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_XAdES_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_JPEG_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_ISO 3166-1 2020 Codes for the representation of names of countries and their subdivisions -- Part 1 Country codes.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the XAdES CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the JPEG CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the ISO 3166-1 2020 Codes for the representation of names of countries and their subdivisions -- Part 1 Country codes CAMSS Assessment EIF 5.0.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_BP_WebData_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_Ogg_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_OpenPM2_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the BP_WebData CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the Ogg CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the OpenPM2 CAMSS Assessment EIF 3.1.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_LDAP_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment_UDDI_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_SVG_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the LDAP CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the UDDI CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the SVG CAMSS Assessment EIF 3.1.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_LegalDocML_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS_Assessment_SOAP 1.2_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS_Assessment_JSON_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the LegalDocML CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the SOAP 1.2 CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the JSON CAMSS Assessment EIF 3.0.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_WS-BPEL_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment_TLS 1.2_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_XHTML_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the WS-BPEL CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the TLS 1.2 CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the XHTML CAMSS Assessment EIF 3.1.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_Xforms 2.0_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_ELI_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_CAdES_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the Xforms 2.0 CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the ELI CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the CAdES CAMSS Assessment EIF 3.1.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_Better_Regulation_Toolbox_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS_Assessment_XML 1.1_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_OASIS Open Data Protocol (Odata).ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the Better_Regulation_Toolbox CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the XML 1.1 CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the OASIS Open Data Protocol (Odata) CAMSS Assessment EIF 5.0.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS_Assessment_XSLT_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_LegalRuleML_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS Assessment ODLR 2.2_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the XSLT CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the LegalRuleML CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the ODLR 2.2 CAMSS Assessment EIF 3.1.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS_Assessment_HTML5 0.1_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment_IPv6_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the REST CAMSS Assessment EIF 5.0.0
# Extracting and initialising migration of the HTML5 0.1 CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the IPv6 CAMSS Assessment EIF 3.0.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_CSS 2.1_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_GITB Test Description Language (TDL).ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the Schema.org CAMSS Assessment EIF 5.0.0
# Extracting and initialising migration of the CSS 2.1 CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the GITB Test Description Language (TDL) CAMSS Assessment EIF 5.0.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS_Assessment_HTTP 1.1_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment_EIF Scenario_PAdES_v.1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_PNG_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the HTTP 1.1 CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the PAdES CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the PNG CAMSS Assessment EIF 3.1.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_TSP_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_ISAE 3402.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_OASIS Topology and Orchestration Specification for Cloud Applications (TOSCA).ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the TSP CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the ISAE 3402 CAMSS Assessment EIF 5.0.0
# Extracting and initialising migration of the OASIS Topology and Orchestration Specification for Cloud Applications (TOSCA) CAMSS Assessment EIF 5.0.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment_UTF-8_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the UTF-8 CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the WAI-ARIA CAMSS Assessment EIF 5.0.0
# Extracting and initialising migration of the WSS CAMSS Assessment EIF 3.0.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_Codes for the representation of names of languages-- Part 2 alpha-3 code (ISO 639-2).ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS_Assessment_PDF 1.7_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment_DCAT-AP_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the Codes for the representation of names of languages-- Part 2 alpha-3 code (ISO 639-2) CAMSS Assessment EIF 5.0.0
# Extracting and initialising migration of the PDF 1.7 CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the DCAT-AP CAMSS Assessment EIF 3.0.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_HTTP State Management Mechanism (HTTP Cookies).ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_PDF_A_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_Network Functions Virtualisation (NFV); Infrastructure Overview (NFVI).ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the HTTP State Management Mechanism (HTTP Cookies) CAMSS Assessment EIF 5.0.0
# Extracting and initialising migration of the PDF_A CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the Network Functions Virtualisation (NFV); Infrastructure Overview (NFVI) CAMSS Assessment EIF 5.0.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment_eDelivery SMP 1.10_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_X.509 Internet Public Key Infrastructure - Online Certificate Status Protocol - OCSP.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_ISO IEC 27001 Information Security Management.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the eDelivery SMP 1.10 CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the X.509 Internet Public Key Infrastructure - Online Certificate Status Protocol - OCSP CAMSS Assessment EIF 5.0.0
# Extracting and initialising migration of the ISO IEC 27001 Information Security Management CAMSS Assessment EIF 5.0.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_Nomenclature of territorial units for statistics (NUTS).ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment_DCAT_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_SMTP_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the Nomenclature of territorial units for statistics (NUTS) CAMSS Assessment EIF 5.0.0
# Extracting and initialising migration of the DCAT CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the SMTP CAMSS Assessment EIF 3.1.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_Skills Framework for the Information Age (SFIA).ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_SMP 2.0_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_TIFF_IT_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the Skills Framework for the Information Age (SFIA) CAMSS Assessment EIF 5.0.0
# Extracting and initialising migration of the SMP 2.0 CAMSS Assessment EIF 3.1.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_MIME_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_CEN TC 428 -  ICT Professionalism and Digital Competences - European Competency Framework (The European Union's European e-Competence Framework (e-CF) (EN 16234-1 e-CF) .ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the TIFF_IT CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the MIME CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the CEN TC 428 -  ICT Professionalism and Digital Competences - European Competency Framework (The European Union's European e-Competence Framework (e-CF) (EN 16234-1 e-CF) CAMSS Assessment EIF 5.0.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment_IPv4_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_HTML4_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment_WSDL_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the IPv4 CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the HTML4 CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the WSDL CAMSS Assessment EIF 3.0.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS_Assessment_CSV_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_Cyber Security for Consumer Internet of Things Baseline Requirements (EN 303 645).ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_PAdES_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the CSV CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the Cyber Security for Consumer Internet of Things Baseline Requirements (EN 303 645) CAMSS Assessment EIF 5.0.0
# Extracting and initialising migration of the PAdES CAMSS Assessment EIF 3.1.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS_Assessment_SAML 2.0_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_XBRL GL (Global Ledger Taxonomy).ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_XACML_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the SAML 2.0 CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the XBRL GL (Global Ledger Taxonomy) CAMSS Assessment EIF 5.0.0
# Extracting and initialising migration of the XACML CAMSS Assessment EIF 3.1.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_CPOV_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment_ASiC Baseline Profile_EIF Scenario_v.1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment of XSD 1.1v.1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the CPOV CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the ASiC Baseline Profile CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the XSD 1.1 CAMSS Assessment EIF 3.0.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_CPSV-AP_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment_IPSec_EIF Scenario_v1.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_EuroVoc_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the CPSV-AP CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the IPSec CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the EuroVoc CAMSS Assessment EIF 3.1.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_ISO 3166-1:2020 Codes for the representation of names of countries and their subdivisions -- Part 1: Country codes.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS_Assessment_XAdES Baseline Profile_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_CLV_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the ISO 3166-1:2020 Codes for the representation of names of countries and their subdivisions -- Part 1: Country codes CAMSS Assessment EIF 5.0.0
# Extracting and initialising migration of the XAdES Baseline Profile CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the CLV CAMSS Assessment EIF 3.1.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS_Assessment_SHACL_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_FTPS_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the SHACL CAMSS Assessment EIF 3.0.0
# Extracting and initialising migration of the FTPS CAMSS Assessment EIF 3.1.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS_Assessment_ODF 1.2_EIF Scenario_v1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.1.0-EIF-3.1.0-CAMSS Assessment - Standard for Public Code v1.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-3.0.0-EIF-3.0.0-CAMSS Assessment_EIF Scenario_CAdES Baseline Profile_v.1.0.0.ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the ODF 1.2 CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the - Standard for Public Code  CAMSS Assessment EIF 3.1.0
# Extracting and initialising migration of the CAdES Baseline Profile CAMSS Assessment EIF 3.0.0
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_OASIS ebXML RegRep.ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_Codes for the representation of names of languages-- Part 2: alpha-3 code (ISO 639-2).ttl does not look like a valid URI, trying to serialize this will break.
# file:///home/mario/github%20repositories/AssessmentCoversor/arti/in/EIF-5.0.0-CAMSSAssessment_European Interoperability Framework (EIF).ttl does not look like a valid URI, trying to serialize this will break.
# Extracting and initialising migration of the OASIS ebXML RegRep CAMSS Assessment EIF 5.0.0
# Extracting and initialising migration of the Codes for the representation of names of languages-- Part 2: alpha-3 code (ISO 639-2) CAMSS Assessment EIF 5.0.0
# Extracting and initialising migration of the European Interoperability Framework (EIF) CAMSS Assessment EIF 5.0.0
# Extracting and initialising migration of the CAMSS_Assessments_graph dataset
#        Migration IN PROGRESS
#
#        Migration of SAMM COMPLETED
#
#        Migration of RDF COMPLETED
#
#        Migration of RegOrg COMPLETED
#
#        Migration of OWL2 COMPLETED
#
#        Migration of HTTPS COMPLETED
#
#        Migration of DNS COMPLETED
#
#        Migration of ADMS COMPLETED
#
#        Migration of FTP COMPLETED
#
#        Migration of CCCEV COMPLETED
#
#        Migration of XAdES COMPLETED
#
#        Migration of JPEG COMPLETED
#
#        Migration of ISO 3166-1 2020 Codes for the representation of names of countries and their subdivisions -- Part 1 Country codes COMPLETED
#
#        Migration of BP_WebData COMPLETED
#
#        Migration of Ogg COMPLETED
#
#        Migration of OpenPM2 COMPLETED
#
#        Migration of LDAP COMPLETED
#
#        Migration of UDDI COMPLETED
#
#        Migration of SVG COMPLETED
#
#        Migration of LegalDocML COMPLETED
#
#        Migration of SOAP 1.2 COMPLETED
#
#        Migration of JSON COMPLETED
#
#        Migration of WS-BPEL COMPLETED
#
#        Migration of TLS 1.2 COMPLETED
#
#        Migration of XHTML COMPLETED
#
#        Migration of Xforms 2.0 COMPLETED
#
#        Migration of ELI COMPLETED
#
#        Migration of CAdES COMPLETED
#
#        Migration of Better_Regulation_Toolbox COMPLETED
#
#        Migration of XML 1.1 COMPLETED
#
#        Migration of OASIS Open Data Protocol (Odata) COMPLETED
#
#        Migration of XSLT COMPLETED
#
#        Migration of LegalRuleML COMPLETED
#
#        Migration of ODLR 2.2 COMPLETED
#
#        Migration of REST COMPLETED
#
#        Migration of HTML5 0.1 COMPLETED
#
#        Migration of IPv6 COMPLETED
#
#        Migration of Schema.org COMPLETED
#
#        Migration of CSS 2.1 COMPLETED
#
#        Migration of GITB Test Description Language (TDL) COMPLETED
#
#        Migration of HTTP 1.1 COMPLETED
#
#        Migration of PAdES COMPLETED
#
#        Migration of PNG COMPLETED
#
#        Migration of TSP COMPLETED
#
#        Migration of ISAE 3402 COMPLETED
#
#        Migration of OASIS Topology and Orchestration Specification for Cloud Applications (TOSCA) COMPLETED
#
#        Migration of UTF-8 COMPLETED
#
#        Migration of WAI-ARIA COMPLETED
#
#        Migration of WSS COMPLETED
#
#        Migration of Codes for the representation of names of languages-- Part 2 alpha-3 code (ISO 639-2) COMPLETED
#
#        Migration of PDF 1.7 COMPLETED
#
#        Migration of DCAT-AP COMPLETED
#
#        Migration of HTTP State Management Mechanism (HTTP Cookies) COMPLETED
#
#        Migration of PDF_A COMPLETED
#
#        Migration of Network Functions Virtualisation (NFV); Infrastructure Overview (NFVI) COMPLETED
#
#        Migration of eDelivery SMP 1.10 COMPLETED
#
#        Migration of X.509 Internet Public Key Infrastructure - Online Certificate Status Protocol - OCSP COMPLETED
#
#        Migration of ISO IEC 27001 Information Security Management COMPLETED
#
#        Migration of Nomenclature of territorial units for statistics (NUTS) COMPLETED
#
#        Migration of DCAT COMPLETED
#
#        Migration of SMTP COMPLETED
#
#        Migration of Skills Framework for the Information Age (SFIA) COMPLETED
#
#        Migration of SMP 2.0 COMPLETED
#
#        Migration of TIFF_IT COMPLETED
#
#        Migration of MIME COMPLETED
#
#        Migration of CEN TC 428 -  ICT Professionalism and Digital Competences - European Competency Framework (The European Union's European e-Competence Framework (e-CF) (EN 16234-1 e-CF) COMPLETED
#
#        Migration of IPv4 COMPLETED
#
#        Migration of HTML4 COMPLETED
#
#        Migration of WSDL COMPLETED
#
#        Migration of CSV COMPLETED
#
#        Migration of Cyber Security for Consumer Internet of Things Baseline Requirements (EN 303 645) COMPLETED
#
#        Migration of PAdES COMPLETED
#
#        Migration of SAML 2.0 COMPLETED
#
#        Migration of XBRL GL (Global Ledger Taxonomy) COMPLETED
#
#        Migration of XACML COMPLETED
#
#        Migration of CPOV COMPLETED
#
#        Migration of ASiC Baseline Profile COMPLETED
#
#        Migration of XSD 1.1 COMPLETED
#
#        Migration of CPSV-AP COMPLETED
#
#        Migration of IPSec COMPLETED
#
#        Migration of EuroVoc COMPLETED
#
#        Migration of ISO 3166-1:2020 Codes for the representation of names of countries and their subdivisions -- Part 1: Country codes COMPLETED
#
#        Migration of XAdES Baseline Profile COMPLETED
#
#        Migration of CLV COMPLETED
#
#        Migration of SHACL COMPLETED
#
#        Migration of FTPS COMPLETED
#
#        Migration of ODF 1.2 COMPLETED
#
#        Migration of - Standard for Public Code  COMPLETED
#
#        Migration of CAdES Baseline Profile COMPLETED
#
#        Migration of OASIS ebXML RegRep COMPLETED
#
#        Migration of Codes for the representation of names of languages-- Part 2: alpha-3 code (ISO 639-2) COMPLETED
#
#        Migration of European Interoperability Framework (EIF) COMPLETED
#
#
#
# You may find the CAMSS Assessments graph in the 'out/CAMSS_Assessments_graph' folder

# %% [markdown]
# ---

# %% [markdown]
# ## Results displayer (% percentage, # integer)

# %% [markdown]
# The scores of individual assessments are located in sub-folders of 'out'.<br><br><b>Keep running the code from this cell.<b>

# %%
display(camss.utils.read_punct())
# Out:
#                                         Specification Previous EIF  \
# 0                                                SAMM        3.1.0
# 1                                                 RDF        3.0.0
# 2                                              RegOrg        3.1.0
# 3                                                OWL2        3.1.0
# 4                                               HTTPS        3.0.0
# 5                                                 DNS        3.0.0
# 6                                                ADMS        3.1.0
# 7                                                 FTP        3.0.0
# 8                                               CCCEV        3.1.0
# 9                                               XAdES        3.1.0
# 10                                               JPEG        3.1.0
# 11  ISO 3166-1 2020 Codes for the representation o...        5.0.0
# 12                                         BP_WebData        3.1.0
# 13                                                Ogg        3.1.0
# 14                                            OpenPM2        3.1.0
# 15                                               LDAP        3.1.0
# 16                                               UDDI        3.0.0
# 17                                                SVG        3.1.0
# 18                                         LegalDocML        3.1.0
# 19                                           SOAP 1.2        3.0.0
# 20                                               JSON        3.0.0
# 21                                            WS-BPEL        3.1.0
# 22                                            TLS 1.2        3.0.0
# 23                                              XHTML        3.1.0
# 24                                         Xforms 2.0        3.1.0
# 25                                                ELI        3.1.0
# 26                                              CAdES        3.1.0
# 27                          Better_Regulation_Toolbox        3.1.0
# 28                                            XML 1.1        3.0.0
# 29                   OASIS Open Data Protocol (Odata)        5.0.0
# 30                                               XSLT        3.0.0
# 31                                        LegalRuleML        3.1.0
# 32                                           ODLR 2.2        3.1.0
# 33                                               REST        5.0.0
# 34                                          HTML5 0.1        3.0.0
# 35                                               IPv6        3.0.0
# 36                                         Schema.org        5.0.0
# 37                                            CSS 2.1        3.1.0
# 38               GITB Test Description Language (TDL)        5.0.0
# 39                                           HTTP 1.1        3.0.0
# 40                                              PAdES        3.1.0
# 41                                                PNG        3.1.0
# 42                                                TSP        3.1.0
# 43                                          ISAE 3402        5.0.0
# 44  OASIS Topology and Orchestration Specification...        5.0.0
# 45                                              UTF-8        3.0.0
# 46                                           WAI-ARIA        5.0.0
# 47                                                WSS        3.0.0
# 48  Codes for the representation of names of langu...        5.0.0
# 49                                            PDF 1.7        3.0.0
# 50                                            DCAT-AP        3.0.0
# 51     HTTP State Management Mechanism (HTTP Cookies)        5.0.0
# 52                                              PDF_A        3.1.0
# 53  Network Functions Virtualisation (NFV); Infras...        5.0.0
# 54                                 eDelivery SMP 1.10        3.0.0
# 55  X.509 Internet Public Key Infrastructure - Onl...        5.0.0
# 56      ISO IEC 27001 Information Security Management        5.0.0
# 57  Nomenclature of territorial units for statisti...        5.0.0
# 58                                               DCAT        3.0.0
# 59                                               SMTP        3.1.0
# 60    Skills Framework for the Information Age (SFIA)        5.0.0
# 61                                            SMP 2.0        3.1.0
# 62                                            TIFF_IT        3.1.0
# 63                                               MIME        3.1.0
# 64  CEN TC 428 -  ICT Professionalism and Digital ...        5.0.0
# 65                                               IPv4        3.0.0
# 66                                              HTML4        3.1.0
# 67                                               WSDL        3.0.0
# 68                                                CSV        3.0.0
# 69  Cyber Security for Consumer Internet of Things...        5.0.0
# 70                                           SAML 2.0        3.0.0
# 71                   XBRL GL (Global Ledger Taxonomy)        5.0.0
# 72                                              XACML        3.1.0
# 73                                               CPOV        3.1.0
# 74                              ASiC Baseline Profile        3.0.0
# 75                                            XSD 1.1        3.0.0
# 76                                            CPSV-AP        3.1.0
# 77                                              IPSec        3.0.0
# 78                                            EuroVoc        3.1.0
# 79  ISO 3166-1:2020 Codes for the representation o...        5.0.0
# 80                             XAdES Baseline Profile        3.0.0
# 81                                                CLV        3.1.0
# 82                                              SHACL        3.0.0
# 83                                               FTPS        3.1.0
# 84                                            ODF 1.2        3.1.0
# 85                        - Standard for Public Code         3.1.0
# 86                             CAdES Baseline Profile        3.0.0
# 87                                 OASIS ebXML RegRep        5.0.0
# 88  Codes for the representation of names of langu...        5.0.0
# 89          European Interoperability Framework (EIF)        5.0.0
#
#    old AUT score (%) new AUT score (%) old STRENG score (%)  \
# 0                 61                85                   59
# 1                 72                97                   68
# 2                 58                79                   64
# 3                 64                86                   66
# 4                 69                93                   66
# 5                 70               100                   52
# 6                 57                77                   68
# 7                 59                79                   66
# 8                 62                83                   66
# 9                 38                55                   50
# 10                49                67                   61
# 11         Undefined         Undefined            Undefined
# 12                41                41                   55
# 13                50                50                   59
# 14                49                49                   70
# 15                65                65                   55
# 16                57                57                   57
# 17                59                56                   66
# 18                62                62                   68
# 19                66                66                   64
# 20                69                69                   66
# 21                57                57                   61
# 22                65                65                   55
# 23                62                60                   68
# 24                52                52                   52
# 25                55                55                   64
# 26                38                38                   50
# 27                61                61                   64
# 28                69                69                   66
# 29         Undefined         Undefined            Undefined
# 30                71                70                   55
# 31                66                66                   70
# 32                68                68                   70
# 33         Undefined         Undefined            Undefined
# 34                71                68                   70
# 35                73                73                   61
# 36         Undefined         Undefined            Undefined
# 37                54                54                   57
# 38         Undefined         Undefined            Undefined
# 39                64                64                   66
# 40                38                38                   50
# 41                41                41                   61
# 42                57                57                   57
# 43         Undefined         Undefined            Undefined
# 44         Undefined         Undefined            Undefined
# 45                69                69                   66
# 46         Undefined         Undefined            Undefined
# 47                61                61                   59
# 48         Undefined         Undefined            Undefined
# 49                61                58                   64
# 50                68                68                   68
# 51         Undefined         Undefined            Undefined
# 52                53                50                   64
# 53         Undefined         Undefined            Undefined
# 54                54                54                   61
# 55         Undefined         Undefined            Undefined
# 56         Undefined         Undefined            Undefined
# 57         Undefined         Undefined            Undefined
# 58                66                66                   68
# 59                55                55                   52
# 60         Undefined         Undefined            Undefined
# 61                49                49                   70
# 62                53                53                   64
# 63                60                60                   57
# 64         Undefined         Undefined            Undefined
# 65                68                68                   61
# 66                62                60                   68
# 67                67                67                   66
# 68                72                72                   59
# 69         Undefined         Undefined            Undefined
# 70                70                70                   61
# 71         Undefined         Undefined            Undefined
# 72                62                62                   50
# 73                55                55                   68
# 74                60                60                   57
# 75                72                72                   66
# 76                63                63                   64
# 77                69                69                   59
# 78                58                58                   64
# 79         Undefined         Undefined            Undefined
# 80                68                68                   55
# 81                55                55                   64
# 82                49                49                   70
# 83                56                56                   66
# 84                51                49                   61
# 85                57                57                   73
# 86                66                66                   57
# 87         Undefined         Undefined            Undefined
# 88         Undefined         Undefined            Undefined
# 89         Undefined         Undefined            Undefined
#
#    new STRENG score (%)  Not Answer (#) Not Applicable (#)  No/Gradient  \
# 0                    60               0                 17            4
# 1                    68               0                 14            1
# 2                    64               0                 16            6
# 3                    66               0                 15            4
# 4                    66               0                 15            2
# 5                    53               0                 20            0
# 6                    68               0                 14            7
# 7                    66               0                 15            6
# 8                    66               0                 15            5
# 9                    51               0                 21           10
# 10                   59               0                 17            8
# 11            Undefined               0          Undefined           10
# 12                   52               0                 10            9
# 13                   57               0                  8            7
# 14                   68               0                  3           10
# 15                   56               0                  9            2
# 16                   58               0                  8            5
# 17                   64               0                  5            6
# 18                   70               0                  3            5
# 19                   64               0                  6            3
# 20                   66               0                  5            2
# 21                   59               0                  7            5
# 22                   56               0                  9            2
# 23                   66               0                  4            5
# 24                   53               0                 10            6
# 25                   64               0                  6            7
# 26                   51               0                 11           10
# 27                   65               0                  5            5
# 28                   66               0                  5            2
# 29            Undefined               0          Undefined            4
# 30                   53               0                 10            0
# 31                   70               0                  3            4
# 32                   70               0                  3            3
# 33            Undefined               0          Undefined            4
# 34                   68               0                  3            2
# 35                   63               0                  6            0
# 36            Undefined               0          Undefined            5
# 37                   55               0                  9            5
# 38            Undefined               0          Undefined           13
# 39                   66               0                  5            4
# 40                   51               0                 11           10
# 41                   59               0                  7           11
# 42                   58               0                  8            5
# 43            Undefined               0          Undefined           11
# 44            Undefined               0          Undefined           11
# 45                   66               0                  5            2
# 46            Undefined               0          Undefined            7
# 47                   60               0                  7            4
# 48            Undefined               0          Undefined            9
# 49                   61               0                  6            5
# 50                   68               0                  4            3
# 51            Undefined               0          Undefined           10
# 52                   61               0                  6            8
# 53            Undefined               0          Undefined           10
# 54                   63               0                  6            7
# 55            Undefined               0          Undefined            3
# 56            Undefined               0          Undefined            9
# 57            Undefined               0          Undefined            6
# 58                   68               0                  3            3
# 59                   53               0                 10            5
# 60            Undefined               0          Undefined           13
# 61                   68               0                  3           10
# 62                   61               0                  6            7
# 63                   58               0                  8            4
# 64            Undefined               0          Undefined            9
# 65                   63               0                  6            2
# 66                   66               0                  4            5
# 67                   66               0                  5            3
# 68                   59               0                  8            0
# 69            Undefined               0          Undefined            9
# 70                   63               0                  6            1
# 71            Undefined               0          Undefined            1
# 72                   51               0                 11            2
# 73                   68               0                  4            8
# 74                   58               0                  8            4
# 75                   66               0                  5            1
# 76                   64               0                  6            4
# 77                   60               0                  7            1
# 78                   64               0                  6            6
# 79            Undefined               0          Undefined           10
# 80                   56               0                  9            1
# 81                   64               0                  6            7
# 82                   70               0                  3           11
# 83                   66               0                  5            7
# 84                   59               0                  7            8
# 85                   73               0                  2            8
# 86                   58               0                  8            2
# 87            Undefined               0          Undefined            3
# 88            Undefined               0          Undefined            9
# 89            Undefined               0          Undefined            4
#
#    Yes/Gradient (#)
# 0                22
# 1                29
# 2                22
# 3                25
# 4                27
# 5                23
# 6                23
# 7                23
# 8                24
# 9                12
# 10               18
# 11        Undefined
# 12               14
# 13               18
# 14               20
# 15               22
# 16               20
# 17               22
# 18               25
# 19               25
# 20               27
# 21               21
# 22               22
# 23               24
# 24               17
# 25               21
# 26               12
# 27               23
# 28               27
# 29        Undefined
# 30               23
# 31               27
# 32               28
# 33        Undefined
# 34               28
# 35               27
# 36        Undefined
# 37               19
# 38        Undefined
# 39               25
# 40               12
# 41               15
# 42               20
# 43        Undefined
# 44        Undefined
# 45               27
# 46        Undefined
# 47               22
# 48        Undefined
# 49               22
# 50               27
# 51        Undefined
# 52               19
# 53        Undefined
# 54               20
# 55        Undefined
# 56        Undefined
# 57        Undefined
# 58               27
# 59               18
# 60        Undefined
# 61               20
# 62               20
# 63               21
# 64        Undefined
# 65               25
# 66               24
# 67               26
# 68               26
# 69        Undefined
# 70               26
# 71        Undefined
# 72               20
# 73               22
# 74               21
# 75               28
# 76               24
# 77               25
# 78               22
# 79        Undefined
# 80               23
# 81               21
# 82               20
# 83               22
# 84               18
# 85               24
# 86               23
# 87        Undefined
# 88        Undefined
# 89        Undefined

# %% [markdown]
# ---

# %% [markdown]
# ## Explore a sample

# %% [markdown]
# <b>Check an arbritary assessment:</b>

# %%
camss.utils.read_files()
# Out:
# @prefix camss: <http://data.europa.eu/2sa#> .
# @prefix camssa: <http://data.europa.eu/2sa/assessments/> .
# @prefix cav: <http://data.europa.eu/2sa/cav#> .
# @prefix cssvrsc: <http://data.europa.eu/2sa/cssv/rsc/> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix org: <http://www.w3.org/ns/org#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix sc: <http://data.europa.eu/2sa/scenarios#> .
# @prefix schema: <http://schema.org/> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix status: <http://data.europa.eu/2sa/rsc/assessment-status#> .
# @prefix tool: <http://data.europa.eu/2sa/rsc/toolkit-version#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# camssa:ce42a35899604f9d542773a5cf82e5230597169d8928f05bcdb2835ac514e088 a owl:NamedIndividual,
#         org:Organization ;
#     camss:contactPoint camssa:e6cf09d1-f0d9-4b77-8a4e-bc7dabd81a9c ;
#     skos:prefLabel "Jääsaari Finnish Tax Administration"@en .
#
# camssa:ecd7b31500b3575985645987cae63917d33c1f0c6fac038c2f97c31f1ba64c8f a cav:Assessment,
#         owl:NamedIndividual ;
#     camss:assesses cssvrsc:90b892f316000b3f7e9c96ff2c0cb7bd8a2e5da58051db814f8471f3e64e4f42 ;
#     camss:assessmentDate "None"^^xsd:date ;
#         camssa:fb0d9f54-095c-46f6-a03f-704f98ff3faf,
#         camssa:fbbbd558-847d-48ff-a6a8-39da2bf4b40d ;
#     cav:status status:Complete ;
#     dct:title "XBRL GL (Global Ledger Taxonomy)"@en .
#
# camssa:0209c30d-5b64-4513-96f9-d3e1106796fd a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-52e41801b0db7274d934a229fee15e657273655d70d448d16706fcbe0e4f9746 ;
#     cav:value "100"^^xsd:int .
#
# camssa:028263e8-f0c1-48d0-9468-bebd89104360 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'With the goal of facilitating a seamless audit trail, XBRL GL is designed to provide an unambiguous linkage
# from underlying events and activities to reporting information and can therefore be used as necessary to
# increase visibility and provide greater comfort in the trustworthiness of underlying content. The XBRL
# specification itself is uniquely designed to provide definitions, descriptions and linkages to regulation,
# practice and guidance for reported data. XBRL GL Profiles, XBRL Formula, and other rules communication
# languages, such as ISO Schematron (as leveraged by Turkey) provides a means for those responsible for
# communicating procedures and requirements in a standardized manner, facilitating “data quality at the front
# door”.
#
# https://specifications.xbrl.org/specifications.html
#
# https://www.edefter.gov.tr/edeftermevzuat.html'"""@en ;
#     cav:refersTo camssa:48683218-8234-4727-a363-1a9bbdc76279 .
#
# camssa:07240a8e-9270-4428-8df4-4938f923bc24 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'There are pilot assessments made in Finland, Nordic countries and Estonia. However these are not official
# assessments endorsed by XBRL International Inc.
#
# https://ec.europa.eu/cefdigital/wiki/display/CEFDIGITAL/2021/03/22/eInvoicing+helping+standardise+transactional+data+in+Estonia
#
# https://www.oecd.org/tax/forum-on-tax-administration/publications-and-products/45045602.pdf : " In their implementation strategy for SAF-T, revenue bodies should consider data formats that
# permit audit automation today while minimising potential costs to all stakeholders when moving to new
# global open standards for business and financial data such as XBRL, and XBRL- GL in particular. " page 10
#
# https://www2.deloitte.com/content/dam/Deloitte/in/Documents/risk/in-risk-xbrl-the-new-world-of-reporting-noexp.pdf
# '"""@en ;
#     cav:refersTo camssa:6dc17b4c-3eff-4dd7-9e7c-ab9156c2a424 .
#
# camssa:08174622-d35f-40fe-b7d9-bd9fb1b6176c a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement "'The specification promotes visibility to business data and harmonizes the data contents thus enabling better usability for the data.'"@en ;
#     cav:refersTo camssa:e212b6c7-e65e-4890-bd8e-1af2fbc7544a .
#
# camssa:084474c8-f8da-44bd-ace6-24a7741bc930 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'XBRL international supports the above by national and international communities to further develop and
# support the implementation of the specification.
#
# https://www.xbrl.org/tag/xbrl-europe/
# https://www.xbrl.org/the-consortium/
# '"""@en ;
#     cav:refersTo camssa:efae49e1-ab72-4885-84d3-d6972d50ca35 .
#
# camssa:087ec3eb-198d-43a5-8149-25c719a1d96d a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-d520eae57650560dd54723cdcdd166243c9a0b1458a4afdc331175b5c1cada7e ;
#     cav:value "40"^^xsd:int .
#
# camssa:104669a4-d808-4614-bcc5-9220fa912062 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The specification can support the semantic layer by offering a taxonomy for business data on transactional
# level.
#
# EIRA Library of Interoperability Specifications (ELIS), these semantic layer would comprise the following ABBs:
#
# Semantic View:
# Representation
# Applicable Profile
#
# Technical View:
# Data Transformation Component
# Data Transformation Service'"""@en ;
#     cav:refersTo camssa:e2fdc32f-f151-4cfd-8c85-159f29921aa4 .
#
# camssa:143ab336-1329-41ab-9361-457db41d064b a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-3dd3a1fb1ac7d78d162dab36230e70a34459f38a795e765cc5fdd304c8c04907 ;
#     cav:value "40"^^xsd:int .
#
# camssa:1e18d540-f470-4d29-bd54-18eb40e92fce a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The specification supports data exchange and business processes among partners. The specification is
# easy to implement into standard business processes.
#
# https://www.xbrl.org/int/gl/2016-12-01/gl-framework-2017-PWD-2016-12-01.html
#
# https://www.dropbox.com/sh/b5i8ehpnzzymowl/AACpTH-mWRwOFGIQkUYDbWoWa/29.10.2021%20Presentations?dl=0&preview=005_TietoEVRY_Symposium_29.10.2021.pdf&subfolder_nav_tracking=1
#
# '"""@en ;
#     cav:refersTo camssa:438c7674-cc40-4f34-baa8-56fa0607ad7f .
#
# camssa:262944b2-39ee-4711-85ea-a9a2c77dca65 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The specification has a validation schema to test conformance. Also automated check rules can be
# implemented.
#
# https://www.xbrl.org/int/gl/2016-12-01/gl-framework-2017-PWD-2016-12-01.html'"""@en ;
#     cav:refersTo camssa:eec9a4de-de83-4cea-8d19-cb34b2236a00 .
#
# camssa:27b23d91-0e58-4bf7-b9e3-23d4b5828133 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-51782b9aa4b92f4aba322a549b9d3972e304ca68f9353073c29add782502d910 ;
#     cav:value "60"^^xsd:int .
#
# camssa:27f164c1-7357-4c89-8c35-9f19ab8a7678 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-3c0edf049cd95575b46d688ed31be0ccce7a5822c5bcc22adf05d491f01f2780 ;
#     cav:value "100"^^xsd:int .
#
# camssa:2e6f1f22-4209-472f-80a9-91d1cd2a2468 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-549e39fc635763b9466e09688714b2908fcf7a349d4f4f0fe2a761bd6f502733 ;
#     cav:value "100"^^xsd:int .
#
# camssa:368760f3-b597-46e1-9cad-33571e3baba9 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-9694ffda6be83e507b6d3395cb411581d91419db0107726873a0a9018eab6a54 ;
#     cav:value "100"^^xsd:int .
#
# camssa:3eac42c0-f6e7-4222-a9ca-0a30ea119ce5 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-1624157830122d60825aa5aa88ab70d0b140b2e7e510086699f9a9773efef6bd ;
#     cav:value "100"^^xsd:int .
#
# camssa:438c7674-cc40-4f34-baa8-56fa0607ad7f a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-22c3c5b40201f4ab2cb64a2d34b7665f8d0d1562f2a3e1a493dd3312608c7537 ;
#     cav:value "100"^^xsd:int .
#
# camssa:48683218-8234-4727-a363-1a9bbdc76279 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-7d12b846c487e7201dbcf395866b5abc0bb5fa040b1f519127b6a5f56d447257 ;
#     cav:value "100"^^xsd:int .
#
# camssa:490ad382-64ff-4fe2-8d87-61b86ffd61a4 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'XBRL GL is machine readable data and as a interface format and does not require special software. XBRL is
# based on XML which is under the W3C.
# XBRL GL has the semantic information of XBRL GL, which can be used to drive Linked Data. The
# specification includes URI references extensively.
# While the primary representation of XBRL GL is with the syntax of XBRL, the semantic is reusable in many
# syntaxes, and unique in its design. XBRL worked closely with the W3C in evaluating the XBRL syntax and
# W3C specifications (https://www.w3.org/2009/02/xbrl-ig/charter.html), noting “Facts, concepts and links in
# XBRL documents can be readily mapped into the Semantic Web. XBRL concepts can be identified via the
# XML namespace for the schema document defining them as elements together with the element name for
# each concept.”
# Related to the levels of 5 star data:
# “make your stuff available on the Web (whatever format) under an open license”
# XBRL GL is freely licensed and royalty free
# “make it available as structured data (e.g., Excel instead of image scan of a table)”
# XBRL GL is a specification for structuring and expressing business data at any level of detail or aggregation
# “make it available in a non-proprietary open format (e.g., CSV instead of Excel)”
# XBRL is a non-proprietary open format. XBRL also can be expressed using JSON, CSV, and other formats.
# “use URIs to denote things, so that people can point at your stuff”
# While XBRL GL’s primary use is within the Enterprise and for data kept confidential by government
# agencies, such as tax filings, URIs are used internally, and the W3C has noted the ease of mapping XBRL
# syntax documents into Linked Data environments.
# “link your data to other data to provide context”
# XBRL GL has been uniquely designed to link both to source data and other contextual information at the
# detail level, and to unambiguously link to summary reporting information at the aggregate level. The SRCD
# portion of the Specification formalizes the summarization of XBRL GL detail to other reported open data. The
# specifications for relating to underlying source information are internally being harmonized with other open
# specifications for relating to other information, as part of other interoperability efforts under UN/CEFACT and
# the ISO.
#
# In this case, XBRL GL is a data representation schema that is based on XML; XBRL GL makes data available in a structured manner aligning with the second-star from Tim Berners-Lee approach. Therefore, the specification facilitates the publication of open data.
#
# About XBRL ( XBRL GL is based on) and linked data in general:
# https://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.232.971&rep=rep1&type=pdf
# '"""@en ;
#     cav:refersTo camssa:bf544ffb-39dd-4c8d-9a9d-31a083589ffc .
#
# camssa:4cdef0fc-721b-4746-8844-3cf75431b361 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-a60f86e868fe2bdcf0c5c47111455d1d5b59498172688e36f23a77baa347d916 ;
#     cav:value "80"^^xsd:int .
#
# camssa:4d609c95-778a-448b-a554-0288fca6c80a a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The specification addresses semantic aspects thus data security and data privacy issues are addresses by
# other means. The specification does not prevent the use of any security means.
# Issues related to authorization and authentication of data are key to its secure processing, and XBRL GL
# was designed with secure processing in mind.'"""@en ;
#     cav:refersTo camssa:5a9098be-d2fe-4252-92da-4b5d49be7dcb .
#
# camssa:4df6691d-91aa-4ba4-8eb1-d6db57d79e40 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-9420538a5a92af199b492414dd056ab7134e456f005895261b1a5b15a3f2814e ;
#     cav:value "100"^^xsd:int .
#
# camssa:5695e185-38c0-43b6-b168-a7f1b5c8a566 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'XBRL International has a special working group that maintains and develops the specification further. The
# working group is open to direct members of XBRL International or its national jurisdictions.
#
# Links to the original source of information and/or references to working groups:
# https://www.xbrl.org/the-consortium/join/
#
# https://www.xbrl.org/the-consortium/members/working-group-enrollment/
# '"""@en ;
#     cav:refersTo camssa:087ec3eb-198d-43a5-8149-25c719a1d96d .
#
# camssa:5a9098be-d2fe-4252-92da-4b5d49be7dcb a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-a2e2820561158593079cf28230b73b9b7f1cb83da49b04d2317790e20c0c706f ;
#     cav:value "100"^^xsd:int .
#
# camssa:6079b82e-e097-4219-98d7-f5463b61368b a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-3beae22dd24b0dbc955ce74a9fe755390983d8436a45b401461ceaaa7a5d1609 ;
#     cav:value "100"^^xsd:int .
#
# camssa:61f14155-4c6c-440e-bee9-fad876bdeaf7 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'Estonia plans wide use of XBRL-GL: "In order to create necessary preconditions for data-driven reporting
# with the public sector and enable companies to exchange machine-readable transaction information, the
# standard XBRL Global Ledger Taxonomy framework has been confirmed. The same standard is
# implemented also in the Estonian Tax and Customs Board “Aruandlus 3.0” (Reporting 3.0) project."
#
# https://www.mkm.ee/en/objectives-activities/real-time-economy/projects
# http://www.baltic-course.com/eng/good_for_business/?doc=159557'"""@en ;
#     cav:refersTo camssa:e3b76569-08ee-463d-af69-c2eb39e5bb84 .
#
# camssa:623e28ac-2845-487f-813d-aab55dca9afe a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'XBRL is used in many MS in external reporting to government, but XBRL GL taxonomy not yet included.
# However there has been developments to use the specification in Estonia and among the Nordic Countries.
# These are under development. It is also worth mentioning the specification is used in
# Turkey.
#
# Estonia: https://itl.ee/en/news/data-driven-reporting-is-the-next-step-in-real-time-economy-sector/
# Turkey (https://www.edefter.gov.tr/edeftermevzuat.html)
# '"""@en ;
#     cav:refersTo camssa:a4318344-5d2e-48dc-983d-d7d57fc5533c .
#
# camssa:648a6f8d-a37e-45b9-9504-de8dd7abd74e a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-9c03a344765a6b8da57c4a7d40647791b737e3e1feecc14e3d59f2c69bdb246b ;
#     cav:value "100"^^xsd:int .
#
# camssa:6ac93c0e-6bb6-4078-ac8c-fc36ae321992 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-f53dee88cf8529a93a68be781005e903c270057da1a72e2f89e8cb154be0c51b ;
#     cav:value "100"^^xsd:int .
#
# camssa:6da9f1a3-618a-4457-b669-db106baa8dd6 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'Estonian Tax and Customs board:
#
# https://www.emta.ee/en/business-client/e-services-training-courses/how-use-e-services/x-tee-services#xbrl-gl'"""@en ;
#     cav:refersTo camssa:368760f3-b597-46e1-9cad-33571e3baba9 .
#
# camssa:6db24096-d9eb-4bd2-bef5-387fb87d6e0a a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-ec3f8a897147f530040ab94fb9bbee9fdad56e7256b2ce6fbb63cf1465315d91 ;
#     cav:value "100"^^xsd:int .
#
# camssa:6dc17b4c-3eff-4dd7-9e7c-ab9156c2a424 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-0e9bb259b84413d890a0fd548e40f255bb983a3add2eb7a737283f711e23d523 ;
#     cav:value "40"^^xsd:int .
#
# camssa:70df58c2-4383-4212-b2e6-00a2d81c9d2d a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The specification can be used as a global ledger by any domain. It can capture a broad set of business
# transaction related data e.g. accounting and taxation related details, parties involved, products or services
# traded.
# '"""@en ;
#     cav:refersTo camssa:defcb0fc-f256-453e-a9c6-ffb5ae7ae63b .
#
# camssa:728fda24-f7d9-481b-b041-3045d6257d54 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-d2c939f8f97b2a02c254da4add5fcbea1311d465178344adc029d82366a0f642 ;
#     cav:value "40"^^xsd:int .
#
# camssa:74902c92-d2a1-4165-88fd-ee5a3ade410e a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The specification addresses semantic aspects thus data security and data privacy issues are addresses by
# other means. The specification does not prevent the use of any security means.
# As noted previously, the chief architect of XBRL GL designed the Specification was deeply engaged in the
# W3C’s security specifications development. While XBRL GL itself does not inherently enable secure
# exchange, it has been designed with secure exchange in mind.'"""@en ;
#     cav:refersTo camssa:6079b82e-e097-4219-98d7-f5463b61368b .
#
# camssa:74a573f8-177f-4582-ba77-2616d09bb389 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The specification can be used as a global ledger by any domain. It can capture a broad set of business
# transaction related data e.g. accounting and taxation related details, parties involved, products or services
# traded. From the beginning of the development of XBRL, the recognition that financial reporting was vitally
# important but not meant to be the complete scope of XBRL led to the rebranding of its first name, XFRML, to
# XBRL. XBRL GL from its inception was designed to be a representation of detailed data across all business
# reporting domains. XBRL participants include financial regulators, sustainability reporting groups, and any
# other area of interest to business reporting stakeholders. XBRL GL was designed to represent holistically
# any area of business reporting, quantitative and qualitative data, in any level of detail from source events
# and business documents to more aggregated and summarized information, using a single, holistic, generic
# and global specification.'"""@en ;
#     cav:refersTo camssa:8b1205c3-75ff-45b7-b377-b98092fd32a5 .
#
# camssa:7605b0d6-dc1d-4cfe-a9de-0ec5ef6ac3dc a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """"There are no requirements on the extent of the implementation of the specification and the extent of the data
# contents being used should vary between use cases. It's recommended to publish sets of requirements per
# implementation.
#
# https://www.xbrl.org/int/gl/2016-12-01/gl-framework-2017-PWD-2016-12-01.html\""""@en ;
#     cav:refersTo camssa:6db24096-d9eb-4bd2-bef5-387fb87d6e0a .
#
# camssa:774856a2-0823-48e4-bf3e-2ac19ed79d6d a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-d9b9ce1d270550422a8ea6097d2ffa1d923267fd681c56280e3b7810a14a580a ;
#     cav:value "100"^^xsd:int .
#
# camssa:7cecfb5f-98d8-4bc9-ac10-e88b8c02c5e8 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-d83a73b3287a82d85b1bd3f5b18089e9794b091b6c6457992a77d5be6bc1500a ;
#     cav:value "100"^^xsd:int .
#
# camssa:852d266d-3e6d-4fbc-adff-d3dfd2c1d31a a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The long-term preservation of data needs to be addresses by other standard means.
# The use of XBRL GL in Turkey for example, leverages digital signatures and certificates so long-term data
# does not need to be maintained centrally; authentication of data maintained at the enterprise is
# accomplished through the certificates that prove the integrity of information provided at a later time.'"""@en ;
#     cav:refersTo camssa:f0b0edb5-5d77-4130-adfa-4b0599f344c8 .
#
# camssa:88a30e58-9989-4d31-a44c-96e0f962b406 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The specification supports data driven service interoperability like opening of data and reporting.
#
# Danish business registry sharing all annual financial statements in XBRL as open data:
# https://datacvr.virk.dk/data'"""@en ;
#     cav:refersTo camssa:9003adcb-00d9-4f87-8ee7-c9c361234f35 .
#
# camssa:89361df4-e3da-4c52-91f4-916c9d6f16c3 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The specification is based on XBRL/XML and might be supported in other data exchange formats in the
# future. The specification takes no stance on what technologies are used in internal business systems.'"""@en ;
#     cav:refersTo camssa:8f1ece02-e50b-43f3-8a5e-739ef3f500f3 .
#
# camssa:8b1205c3-75ff-45b7-b377-b98092fd32a5 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-25deb65536af2c7e82f921c56df2c7e21093b2c06fdddd63021b4bccea0b9cd7 ;
#     cav:value "100"^^xsd:int .
#
# camssa:8f1ece02-e50b-43f3-8a5e-739ef3f500f3 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-69e927013383f3944a629c01e930a6663b8304aa5f3137b9a5de3c02d34da401 ;
#     cav:value "100"^^xsd:int .
#
# camssa:9003adcb-00d9-4f87-8ee7-c9c361234f35 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-e225f44a0b0939b1b30a1ab03b2f38baeca8699c0cd44b4e39adbe19ffbb3542 ;
#     cav:value "100"^^xsd:int .
#
# camssa:930dcc24-1256-43b7-984d-352446455d58 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'XBRL international supports the above by national and international communities to further develop and
# support the implementation of the specification.
# e.g. https://fi.xbrl.org/, https://www.xbrl.org/tag/spain/
#
# XBRL GL provides a standardized toolset for the broad adoption of relevant data standardization, but the
# developers recognized that local extensions and variations will be necessary. Under the auspices of local
# XBRL jurisdictions or other organizations, further standardization leveraging XBRL GL are expected,
# encouraged and facilitated.
#
# http://www.xbrl.org/int/gl/2015-03-25/GLTFTA-REC-2015-03-25.html#section-how-to-create-extensions-within-the-gl-taxonomy-framework
# '"""@en ;
#     cav:refersTo camssa:3eac42c0-f6e7-4222-a9ca-0a30ea119ce5 .
#
# camssa:932a018e-8992-45fe-96c0-b8d1560872e0 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement "'Data portability is one of the key attributes of the specification.'"@en ;
#     cav:refersTo camssa:e7bca7e8-39c0-4f63-afbc-fcf32e5417d8 .
#
# camssa:96b221f3-9545-4603-9eb5-56c900f38253 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'XBRL International and the community around it provides support for the specification.
# National XBRL organisations provide support to members.
#
# https://www.xbrl.org/guidance/'"""@en ;
#     cav:refersTo camssa:c89d5228-e5ad-470d-acf2-19b7b98d5639 .
#
# camssa:9a96bb53-d26b-4ff8-910f-33db0e24af51 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'Estonia reporting 3.0 program and Nordic smart government.
#
# https://nordicsmartgovernment.org/
# https://www.stat.ee/en/reporting-30
# https://realtimeeconomy.ee/
# https://www.dropbox.com/sh/b5i8ehpnzzymowl/AACpTH-mWRwOFGIQkUYDbWoWa/29.10.2021%20Presentations?dl=0&preview=004_Estonian+reporting+mapping+and+a+new+model+copy.pdf&subfolder_nav_tracking=1
# '"""@en ;
#     cav:refersTo camssa:a69e2dbb-a0b2-4c9f-a78c-703abea3df75 .
#
# camssa:9e57e9f4-adc4-4602-8f4d-6ce0d3c17a29 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-b37687b8bb3dbd4c6f96969358cf5d70900d1ccd01402cea7668da6303bec4b4 ;
#     cav:value "60"^^xsd:int .
#
# camssa:a02ab4e1-c2f2-448c-8445-b52e647951f7 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The underlying XBRL specification was designed to permit not only the capture and expression of business
# reporting facts in all of the languages supported by ISO 639, but also the internal capture and expression of
# regulation and guidance related to the reporting content. The specification has support already for 8
# languages and the process for adding new ones is defined.
#
# http://www.xbrl.org/specification/xbrl-2.1/rec-2003-12-31/xbrl-2.1-rec-2003-12-31+corrected-errata-2013-02-20.html'"""@en ;
#     cav:refersTo camssa:b5d81820-3d28-4bf7-9e35-fef38b98f7f4 .
#
# camssa:a40df87a-5b49-4a02-a8fe-c52d1f96850c a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The specification is more towards semantic interoperability and does not adress UX and data representation
# layers.'"""@en ;
#     cav:refersTo camssa:9e57e9f4-adc4-4602-8f4d-6ce0d3c17a29 .
#
# camssa:a4318344-5d2e-48dc-983d-d7d57fc5533c a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-812668363d8f0cc562041fae6c588e1555372bf0bf5c16835be996dd72070013 ;
#     cav:value "20"^^xsd:int .
#
# camssa:a672f57a-8f98-44fc-a61e-182ffa0c6081 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-e46f1a4a060cc7e143e32e4833c94af9164c37bc0d4c844bd1fa974ffb2ac225 ;
#     cav:value "100"^^xsd:int .
#
# camssa:a69e2dbb-a0b2-4c9f-a78c-703abea3df75 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-a6184fb705cfed44856c7b9594b492926f7a63a128a5a2be7b896294d8c79838 ;
#     cav:value "100"^^xsd:int .
#
# camssa:b5a43c08-91bf-4b62-9cb4-707a88648499 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The first drafts of XBRL GL were developed in 1999 by the chief architect who contributed the work to XBRL.
# Development and implementation of pre-recommendation status versions followed shortly after (See
# http://www.xbrl.org/business/companies/breathing-new-life-into-old-systems.pdf from 2004, for example).
# The standards process within XBRL led to the first official version in 2005.
# The Specification was not developed in a background. Its chief architect and other participants also
# contributed to virtually all other Specifications in overlapping space, including UN/CEFACT Accounting and
# Audit artefacts, OECD Standard Audit File for Taxation (SAF-T), ISO/TC 295’s Audit Data Collection
# specification ISO 21378:2019, AICPA Audit Data Standards, and others, each focusing on some specific
# area or compliance. This collaboration was to encourage harmonization and help in proving the capabilities
# of XBRL GL.
#
# https://www.xbrl.org/int/gl/2007-04-17/GLFramework-REC-2007-04-17.htm
#
# All versions: https://specifications.xbrl.org/spec-group-index-xbrl-gl.html
# '"""@en ;
#     cav:refersTo camssa:6ac93c0e-6bb6-4078-ac8c-fc36ae321992 .
#
# camssa:b5cbdfd2-1156-4413-8268-5b2f8bfe7be6 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-ceebc7042ff4b3525981f67e306167d9711ac0bce6ea07a067cdb4881854db97 ;
#     cav:value "100"^^xsd:int .
#
# camssa:b5d81820-3d28-4bf7-9e35-fef38b98f7f4 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-26d7b17ff73e55cbf2e7b90ec0eaca8627f132b000e1c8f2de8e5157d8ebe216 ;
#     cav:value "100"^^xsd:int .
#
# camssa:ba469957-4406-4e07-91b8-c2c98b05aa70 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The specification can be used as an annex in interoperability agreements.
# Through the use of XBRL GL Profiles, organisations that wish to interchange data can communicate and
# agree upon the scope, amount, and restrictions on the data to be interchanged and, where feasible,
# automate the evaluation of conformation and data quality being exchanged.'"""@en ;
#     cav:refersTo camssa:27b23d91-0e58-4bf7-b9e3-23d4b5828133 .
#
# camssa:bb84742c-dea4-4659-91bb-92878a4da149 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'There are clear guidelines for customisation and extensions for the specification.
#
# http://www.xbrl.org/int/gl/2015-03-25/GLTFTA-REC-2015-03-25.html#section-how-to-create-extensions-within-the-gl-taxonomy-framework'"""@en ;
#     cav:refersTo camssa:774856a2-0823-48e4-bf3e-2ac19ed79d6d .
#
# camssa:bf544ffb-39dd-4c8d-9a9d-31a083589ffc a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-8c0e1d9d02fa1d534bed0962df3492708c99afbc6343ac8dc671bbabae75aca2 ;
#     cav:value "100"^^xsd:int .
#
# camssa:c266e61d-9dd4-441d-8588-e95dd0c9bcae a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'While the XBRL specification explicitly notes that security, privacy and confidentiality are not directly in
# scope for XBRL, the chief architect of XBRL GL developed the structure of XBRL GL based on more than 10
# years working with the XML security efforts of the W3C and is a named contributor to the XML Encryption
# specification. In particular, personally identifiable information is segregated and standardized to simplify
# encryption and other protection efforts.
#
# This issue of data protection is dependent on other specifications or technologies like the XML Encryption.
#
# '"""@en ;
#     cav:refersTo camssa:143ab336-1329-41ab-9361-457db41d064b .
#
# camssa:c79c7626-3c6a-4e07-b73b-7b3cfd97fb1a a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'XBRL International has a public reviewing period for all of its specifications.
# XBRL GL consultations can be conducted by XBRL International members and " volunteers" using the "public working drafts".
#
# These public working drafts are available  in
# https://specifications.xbrl.org/spec-group-index-xbrl-gl.html
#
# https://www.xbrl.org/the-consortium/get-involved/navigating-your-journey-as-a-volunteer/the-standards-development-process-overview/
#
# Please see also  further instructions on how to contribute or take part in the specification development:
# https://specifications.xbrl.org/faq.htm'"""@en ;
#     cav:refersTo camssa:f2152227-7cf4-4f59-af1a-d93eba3640f1 .
#
# camssa:c7ef87f4-b725-4a48-a236-02f710ab1a45 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'Estonia:
#
# https://www.emta.ee/en/business-client/e-services-training-courses/how-use-e-services/x-tee-services#xbrl-gl
#
#
# https://www.emta.ee/en/business-client/e-services-training-courses/how-use-e-services/x-tee-services#materials
# '"""@en ;
#     cav:refersTo camssa:2e6f1f22-4209-472f-80a9-91d1cd2a2468 .
#
# camssa:c89d5228-e5ad-470d-acf2-19b7b98d5639 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-fb2c0a4ddb03b09ecd5450c5a1d6aeed4e51c2a0387709a95a89cd850a7dd180 ;
#     cav:value "80"^^xsd:int .
#
# camssa:c992d706-f3b6-4443-9028-e0d0f6ffed74 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement "\"The specification takes no stance on what technologies are used in the platform it's being used on.\""@en ;
#     cav:refersTo camssa:4df6691d-91aa-4ba4-8eb1-d6db57d79e40 .
#
# camssa:c9d252cc-a1c2-4b3f-9e39-60dd3475aadd a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'There are public pilot assessments made in Finland, Nordic countries and Estonia. However these are not
# official assessments endorsed by xbrl international.
#
# https://www.suomidigi.fi/sites/default/files/2020-12/Interaktiiviset%20tuotokset.pdf'"""@en ;
#     cav:refersTo camssa:728fda24-f7d9-481b-b041-3045d6257d54 .
#
# camssa:d1d4fc9d-512f-4f6c-9e73-24d68fbd1564 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'No royalties are to be paid for the usage of the specification.
# XBRL GL was developed by an international consortium with a major focus on financial regulators and
# administrators; the specifications are freely licensed and royalty free. The only restrictions are those imposed
# by XBRL’s intellectual property policies and trademark rules.
#
# https://xbrl.us/home/about/legal/'"""@en ;
#     cav:refersTo camssa:f76a088b-9000-4433-9b1c-fd55aed15417 .
#
# camssa:d1d7dc10-eb0a-43ab-9651-9867b803a879 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The XBRL specifications including XBRL GL are publicly available.
#
# https://specifications.xbrl.org/specifications.html'"""@en ;
#     cav:refersTo camssa:0209c30d-5b64-4513-96f9-d3e1106796fd .
#
# camssa:d24c83c1-217c-417c-8b48-6e8b7d556abb a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-17a2b7a0ca372f407c300b69049faf9d92cbf274964290ba278b18cf10bf5dbf ;
#     cav:value "100"^^xsd:int .
#
# camssa:dc0cc66f-f1e5-448e-af37-63d495b0fa62 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The specification is development for the evolution of interoperability.
# The development of XBRL GL comes with close relationships with European public services participants
# through collaboration in the development of OECD’s SAF-T and UN/CEFACT’s accounting and audit
# artefacts, as well as international collaboration through the ISO.
#
# https://docs.google.com/spreadsheets/d/1a1HJJJfwsLUbLvJzQ9hQ-ZGtiz2peyGt/edit?usp=sharing&ouid=117964998322026798794&rtpof=true&sd=true'"""@en ;
#     cav:refersTo camssa:27f164c1-7357-4c89-8c35-9f19ab8a7678 .
#
# camssa:dd1aea2a-437a-45a7-b22b-50d3887f01f8 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'COMMISSION IMPLEMENTING DECISION (EU) 2016/120: "The XBRL 2.1 should therefore be identified as
# ICT technical specification eligible for referencing in public procurement," and " The eXtensible Business
# Reporting Language version 2.1 is eligible for referencing in public procurement." XBRL GL is a taxonomy
# based on xbrl.
#
# https://eur-lex.europa.eu/legal-content/EN/TXT/?toc=OJ%3AL%3A2016%3A023%3ATOC&uri=uriserv%3AOJ.L_.2016.023.01.0077.01.ENG
# '"""@en ;
#     cav:refersTo camssa:d24c83c1-217c-417c-8b48-6e8b7d556abb .
#
# camssa:defcb0fc-f256-453e-a9c6-ffb5ae7ae63b a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-50ab6a29689585b917f7b2972d2c41e8c8c52723c2d58eb9b92109c938d4e825 ;
#     cav:value "100"^^xsd:int .
#
# camssa:e10ff7bb-e59e-4fa4-86b1-0fddfa8a2b17 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The specification is developed as a common interface.
# XBRL GL facilitates the publication of open data in many ways.
# A primary goal of open data is that it be usable, and usability is enhanced by reliability. As an important
# facilitator of a seamless audit trail, XBRL GL is able to represent data from initial source events, activities or
# documents through to summarization. As such, it can represent data at any level of detail, and standardize
# the communication of data appropriate to be open.
# XBRL GL provides a single framework for information both quantitative and qualitative related to business
# reporting at any level of detail. In conjunction with any standardized code sets, it provides a single structure
# for expressing the representation of data.
#
# '"""@en ;
#     cav:refersTo camssa:a672f57a-8f98-44fc-a61e-182ffa0c6081 .
#
# camssa:e212b6c7-e65e-4890-bd8e-1af2fbc7544a a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-26aeec3cf5b3b4879325e85fcd751d0c17f62c6c3113109fb100883a553ec0af ;
#     cav:value "80"^^xsd:int .
#
# camssa:e2fdc32f-f151-4cfd-8c85-159f29921aa4 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-583a0f52df591048a41be40620830a70260e77855364174d91ba159970d8488e ;
#     cav:value "100"^^xsd:int .
#
# camssa:e3b76569-08ee-463d-af69-c2eb39e5bb84 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-0b122f4f42ca2089ee158a31d932d6a0332aa3a4d04acce1e2e7aa140815a0ec ;
#     cav:value "100"^^xsd:int .
#
# camssa:e594e906-2f8b-4234-a335-9507cd20b44f a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The specification supports and makes possible reporting for different needs from the same data.
# The well-documented vision of XBRL GL driving its development was “A piece of business information, once
# entered into any computer, anywhere, never needs to be retyped as it flows through the business reporting
# supply chain.”
#
# http://raw.rutgers.edu/carlab/Cohen.html'"""@en ;
#     cav:refersTo camssa:b5cbdfd2-1156-4413-8268-5b2f8bfe7be6 .
#
# camssa:e6cf09d1-f0d9-4b77-8a4e-bc7dabd81a9c a schema:ContactPoint,
#         owl:NamedIndividual ;
#     schema:email "jussi.jaasaari@vero.fi" .
#
# camssa:e7bca7e8-39c0-4f63-afbc-fcf32e5417d8 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-c8a79448e829e27f47318879de4899c3a6404aa66d7d8954e7a680cf6e5d1ca2 ;
#     cav:value "100"^^xsd:int .
#
# camssa:eec9a4de-de83-4cea-8d19-cb34b2236a00 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-a6fa642bc8eceff2b1d333dc1123748399264c028fde2fd78308f0a0209ae21b ;
#     cav:value "100"^^xsd:int .
#
# camssa:efae49e1-ab72-4885-84d3-d6972d50ca35 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-cc272cd8a2e3e9c5e4edaa5ac7d59735c377a9db89d6958335a2cf0538761ab3 ;
#     cav:value "100"^^xsd:int .
#
# camssa:f0b0edb5-5d77-4130-adfa-4b0599f344c8 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-245e5eb8db3a19aebfdf9ccc2c2ac0467bebccc76339696f519452e8bbd393ad ;
#     cav:value "40"^^xsd:int .
#
# camssa:f0cc116c-dc2e-46ce-9756-f3b107a75126 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-bb5b5da7c1dc98a64c6a6f22f8fc539a8f80702f896697e985dd2c06d4ab68aa ;
#     cav:value "100"^^xsd:int .
#
# camssa:f2152227-7cf4-4f59-af1a-d93eba3640f1 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-3b3b2febe9a7e3ad44bdefc47b0bbcafc7a2e677e9570d6ad822efbe1f7d41e2 ;
#     cav:value "100"^^xsd:int .
#
# camssa:f5e7227c-1d0e-4046-9e69-bb9f63ac9be6 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The specification supports data driven service interoperability like opening of data and reporting.
#
# Danish business registry sharing all annual financial statements in XBRL as open data:
# https://datacvr.virk.dk/data'"""@en ;
#     cav:refersTo camssa:648a6f8d-a37e-45b9-9504-de8dd7abd74e .
#
# camssa:f76a088b-9000-4433-9b1c-fd55aed15417 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-cd828c0ec9887027bdb6b981560bde593cda27c080298ab36323ba5441ba4c31 ;
#     cav:value "100"^^xsd:int .
#
# camssa:fabf9dbb-5a28-4916-9356-d07af17f5ceb a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The specification acts as an interface and enables the business transaction level data being shared and
# reused in different systems - internal or external.
#
# https://unece.org/fileadmin/DAM/cefact/cf_forums/2019_Geneva/Conf_AccountAudit/PPT_1_2_XBRL_Koskentalo.pdf
#
# http://www.xbrl.org/GLWGNotes/XBRL-GL-WGN-FAQ-2007-08-01.htm
# '"""@en ;
#     cav:refersTo camssa:f0cc116c-dc2e-46ce-9756-f3b107a75126 .
#
# camssa:fb0d9f54-095c-46f6-a03f-704f98ff3faf a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'There are clear guidelines for customisation and extensions for the specification.
#
# http://www.xbrl.org/int/gl/2015-03-25/GLTFTA-REC-2015-03-25.html#section-how-to-create-extensions-within-the-gl-taxonomy-framework'"""@en ;
#     cav:refersTo camssa:7cecfb5f-98d8-4bc9-ac10-e88b8c02c5e8 .
#
# camssa:fbbbd558-847d-48ff-a6a8-39da2bf4b40d a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'The implementation of the specification is still underway in Finland and Estonia.
# The mandate for the use of XBRL GL by all companies with any significant sales in Turkey is an indication of
# the impact on ERP developers for those enterprises to implement XBRL GL in their systems.
#
# Estonia: https://ec.europa.eu/digital-building-blocks/wikis/display/CEFDIGITAL/2021/03/22/eInvoicing+helping+standardise+transactional+data+in+Estonia
#
# Turkey: https://www.ifrs.org/content/dam/ifrs/publications/jurisdictions/filing-profiles/turkey-18-november-2015.pdf
#
# https://www.edefter.gov.tr/edeftermevzuat.html
#
# '"""@en ;
#     cav:refersTo camssa:4cdef0fc-721b-4746-8844-3cf75431b361 .

# %% [markdown]
# ---

# %% [markdown]
# ## Explore a sample

# %% [markdown]
# <b>Check an arbritary assessment:</b>

# %%
camss.utils.read_assessments_graph()
# Out:
# @prefix camss: <http://data.europa.eu/2sa#> .
# @prefix camssa: <http://data.europa.eu/2sa/assessments/> .
# @prefix cav: <http://data.europa.eu/2sa/cav#> .
# @prefix cccev: <http://data.europa.eu/m8g/cccev#> .
# @prefix cssvrsc: <http://data.europa.eu/2sa/cssv/rsc/> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix org: <http://www.w3.org/ns/org#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix sc: <http://data.europa.eu/2sa/scenarios#> .
# @prefix schema1: <http://schema.org/> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix status: <http://data.europa.eu/2sa/rsc/assessment-status#> .
# @prefix tool: <http://data.europa.eu/2sa/rsc/toolkit-version#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# camssa:060a5380b24b20ba703a48672ee51f26fd812f6154c129e2140eccbeb29ca84b a cav:Assessment,
#         owl:NamedIndividual ;
#     camss:assesses cssvrsc:0df446c93fc7fc59add5449d846f47101b10b6e30e88a143d6c523aad8117c28 ;
#     camss:assessmentDate "None"^^xsd:date ;
#     camss:submissionDate "None"^^xsd:date ;
#     camss:toolVersion tool:5.1.0 ;
#     cav:contextualisedBy sc:87c1faa38c024ef8225a36b2c5d472986ac937ab61b86d8e80edd5468c4eab28 ;
#     cav:resultsIn camssa:0f15bf32-db08-4c70-a7e1-df549f1114da,
#         camssa:211b16a7-4ad2-4d37-86a4-50325d90422f,
#         camssa:24853455-4ad0-4067-b809-978543430776,
#         camssa:37154e61-98ee-4b2f-8ed3-56520cf105e3,
#         camssa:40fc4a06-42ab-4dca-bf1f-570d8f5a6caa,
#         camssa:4c8a2379-faa6-4189-bdd0-92ff0aa0e527,
#         camssa:500bf167-9669-4d5c-92e9-134ae8ff40fa,
#         camssa:59a25f35-175b-41b1-91c3-bfc48de46c11,
#         camssa:5c98ae7c-e314-46e6-b920-2a8781792807,
#         camssa:6255ddb7-dbac-45e1-8f0e-17056d6508b0,
#         camssa:68b814fd-036e-42b5-86f4-99c0915541dd,
#         camssa:6ad03a23-3eee-4a1c-b0e6-9eb7aca85d7f,
#         camssa:71897107-7899-4cd5-848f-378cd6f939e3,
#         camssa:745591f2-4ccd-4433-a8f3-b3094751f47e,
#         camssa:76dccb8c-0d82-4eea-bdab-f5ac0f9c9101,
#         camssa:7ff7a07c-d4bc-43b6-a52b-518e4eb3fe00,
#         camssa:81d29a4d-0f95-4b2a-bc30-1e5d8154d188,
#         camssa:889136e0-81d9-43b7-a093-7c4455c612d0,
#         camssa:88faf175-f62b-4fd1-bfbd-a5c7dc6dee8e,
#         camssa:896abf65-12a2-422b-9496-2e2da96870ec,
#         camssa:93f4451e-5484-42d2-9989-c90ad5c1947a,
#         camssa:99f51d95-f2d4-410c-8703-aa4f896d081f,
#         camssa:9dd966a5-2db0-4bf6-b08f-452dde3d406c,
#         camssa:a0cb81cd-028a-4f6f-8123-c27df48957d0,
#         camssa:a11e9eee-4025-4585-bf43-d7043d5be07a,
#         camssa:a149e3df-31d9-452e-8b9e-42f1cf815f7c,
#         camssa:05e854dd-e250-4a24-ba4e-b1fc17960763,
#         camssa:065dbf2f-b685-401e-b37c-1b8d5d7c267b,
#         camssa:0661dcf3-f5be-48bc-bf80-91bb365c43af,
#         camssa:07ab7e53-e76a-4ad9-920d-82630e2ea78b,
#         camssa:0b8d3bb6-8a63-4fa7-b2d4-efb1003b45ec,
#         camssa:0d603e1d-4369-439f-ad07-9b3d066eb4fb,
#         camssa:12dfe797-c567-47b2-a73a-39e3294b9a7f,
#         camssa:17d89b9f-79ae-40e4-89fa-e0ae58e86e6d,
#         camssa:1cf5ef5e-dc9f-4f46-beac-18934812ba2d,
#         camssa:202e1d1f-d1e2-4e93-bc5c-6913b71b008c,
#         camssa:243bed26-d4b2-4b95-ac89-77e9c64d82ba,
#         camssa:32aa92ea-652f-4301-93e8-05aae159d0ad,
#         camssa:34d8fc67-0b80-4a1f-81d1-b3fd4742b382,
#         camssa:41618c00-a0e4-4811-af70-dd333ed3b14b,
#         camssa:4459db6c-863b-424a-9068-90b6edf8428b,
#         camssa:50c19d25-33d6-4ce1-804c-a60f3c16de9c,
#         camssa:5744cb56-0258-4446-b226-a8d62d81312a,
#         camssa:634b9501-774f-4bb9-8e31-e7d11ec2da14,
#         camssa:656c602b-a3bf-4285-a5fe-fa47286cd77f,
#         camssa:6587446d-76d3-406c-ba3e-7a79aadcaad5,
#         camssa:6aade367-a1e5-476f-991a-4103d5c1a061,
#         camssa:6e3556ce-edf8-4754-a8f0-142f6f3a36be,
#         camssa:7447fc81-13bb-4a35-a4f2-f76fcd631623,
#         camssa:78cf00a6-7bdc-4eb2-bee2-42e0348ecca7,
#         camssa:7a6200bd-d46c-4cbf-8bf4-2d5a7a0f0c7d,
#         camssa:872f29ca-6794-478c-8364-fc8eb18c04a0,
#         camssa:8ba81dfa-d838-452b-9db8-aa6846550d47,
#         camssa:91ede15e-e3c4-4a44-83a8-33a40e2214ad,
#         camssa:95bea485-3bb2-4c11-a337-ebdcca9a99f4,
#         camssa:9b5af140-9e02-41c0-af71-51ad64a23b48,
#         camssa:a417d1f9-34fd-4959-9ec4-4f8ef9eba6de,
# ...
#
# Moreover, the Working Group in charge of its development has the aim to promote ODRL V2.2 to existing and new sectors/industries.
#
# W3C ODRL Community:
# https://github.com/w3c/odrl"""@en ;
#     cav:refersTo camssa:efd86853-127c-42c1-ae00-2e181a18f5b0 .
#
# camssa:e91222ac-6fc4-40b6-b34b-a30ae07b93af a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-e225f44a0b0939b1b30a1ab03b2f38baeca8699c0cd44b4e39adbe19ffbb3542 ;
#     cav:value "100"^^xsd:int .
#
# camssa:e9137d37-9c95-45b3-a9b0-ed9642400ec9 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """OASIS has defined a clear Technical Committee (hereby TC) process where all the stakeholders involved has the opportunity to participate in the development of the specification being formulated.
# All the information related to a TC activity is hosted and can be consulted.
# See:
# https://www.oasis-open.org/policies-guidelines/tc-process-2017-05-26"""@en ;
#     cav:refersTo camssa:dedeb339-883c-4a3c-9f2b-ac882038bda7 .
#
# camssa:e925d530-96c0-4659-95cd-ba8b848a1ea6 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-22c3c5b40201f4ab2cb64a2d34b7665f8d0d1562f2a3e1a493dd3312608c7537 ;
#     cav:value "100"^^xsd:int .
#
# camssa:e9270108-27eb-48d8-8b9a-265af4748405 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'ISO/IEC 27001 is included in the Catalogue of standards of Norway.
#
# Norway catalogue of standards:
# https://joinup.ec.europa.eu/collection/common-assessment-method-standards-and-specifications-camss/camss-list-standards'"""@en ;
#     cav:refersTo camssa:1c1c0420-89b2-4d23-9dd0-ed64fbda0a9f .
#
# camssa:e92a82c9-b75c-426b-a335-3922bc513fca a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """TSP is developed and maintained by IETF, a widely recognised open international community developing standards to enhance the internet.
#
# IETF Reference:
# https://www.ietf.org/
#
# TSP IETF reference:
# https://tools.ietf.org/html/rfc3161"""@en ;
#     cav:refersTo camssa:614e2711-2d5e-49cd-a0f4-7c9268f0cbbf .
#
# camssa:e94999ad-0aed-44fa-9f25-8cae30832c61 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement "None"@en ;
#     cav:refersTo camssa:cd6e8c26-5820-410d-957d-a688251a92c1 .
#
# camssa:e9590511-67cf-4ada-b1eb-a975ee23d2ff a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement "The specification allows the exchange of authentication and authorization data between parties. It is mainly used to ensure single sign-on (SSO).  It extends SSO across security domains independently from any platform which prevents non-interoperable proprietary technologies. For instance, a relevant implementation of SAML 2.0 is SAML Web Browser SSO profile. This profile was specified to promote interoperability by allowing the authentication to service providers through external identity providers. "@en ;
#     cav:refersTo camssa:586478ce-12bd-4bf5-a7c0-3343b54e982c .
#
# camssa:e95daffc-273e-4444-a377-2f8f5184f7a0 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-cd828c0ec9887027bdb6b981560bde593cda27c080298ab36323ba5441ba4c31 ;
#     cav:value "100"^^xsd:int .
#
# camssa:e96b5d94-81cd-4d07-b5ed-e9594b1e6c01 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-b37687b8bb3dbd4c6f96969358cf5d70900d1ccd01402cea7668da6303bec4b4 ;
#     cav:value "100"^^xsd:int .
#
# camssa:e978fa32-8057-4583-ba54-76664cc2e8d9 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'ISO 639-2 has been extensively used in the library industry and can also be used for any domain that requires the expression of language in codes. This specification has been implemented in other domains where a linguistic solution was needed, for example in e-procurement (eForms).
#
# ISO 369-2 FAQs:
# https://www.loc.gov/standards/iso639-2/faq.html#5
#
# eForms Language reference:
# https://docs.ted.europa.eu/eforms/0.5.0/codelists/index.html#_tailored_codelists'"""@en ;
#     cav:refersTo camssa:9f0fc5d8-3e43-4c9a-be2f-1d10fdf19865 .
#
# camssa:e9931f91-c416-4b3c-b8b2-74e20ffa7f78 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-3beae22dd24b0dbc955ce74a9fe755390983d8436a45b401461ceaaa7a5d1609 ;
#     cav:value "100"^^xsd:int .
#
# camssa:e995536d-6ae8-409f-b11f-1b1c1369cad4 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement "The main purpose of PAdES baseline profile is not related to the preservation of digital information or items. Although, the different profiles defined by the specification are related to the long-term preservation of eSignatures and the materials related to the validation. This capability ensures the availability of signatures and related materials within a long period according to the needs of each implementer. "@en ;
#     cav:refersTo camssa:baaf240f-5251-4539-a656-81f92207b6b2 .
#
# camssa:e9a5aa9e-cae8-42fe-a166-91fb19aa7897 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """After being evaluated compliant with the regulation on standardisation 1025/2012, IPv6 has been identified by Commission Implementing Decision and included in the European list of ICT Standards for e-procurement.
#
# See:
# https://ec.europa.eu/growth/industry/policy/ict-standardisation/ict-technical-specifications_en
# """@en ;
#     cav:refersTo camssa:6212c421-4749-4d5b-9fde-fa24f575e8e1 .
#
# camssa:e9a7883f-e2ad-47cc-b6c7-23609b06215e a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-3b3b2febe9a7e3ad44bdefc47b0bbcafc7a2e677e9570d6ad822efbe1f7d41e2 ;
#     cav:value "100"^^xsd:int .
#
# camssa:e9b158c1-d678-40ed-a0fe-342058942180 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement "None"@en ;
#     cav:refersTo camssa:5df41051-d304-4d8e-8340-74821e8e11a2 .
#
# camssa:e9b6ce0c-0bbd-4391-b0b3-db099c8a5c33 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-e225f44a0b0939b1b30a1ab03b2f38baeca8699c0cd44b4e39adbe19ffbb3542 ;
#     cav:value "100"^^xsd:int .
#
# camssa:e9be89ca-96ef-4e09-ad3c-3b115d2902d6 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-1624157830122d60825aa5aa88ab70d0b140b2e7e510086699f9a9773efef6bd ;
#     cav:value "100"^^xsd:int .
#
# camssa:e9c8c802-abe8-4a9c-ad8d-d94469eab80d a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-bb5b5da7c1dc98a64c6a6f22f8fc539a8f80702f896697e985dd2c06d4ab68aa ;
#     cav:value "100"^^xsd:int .
#
# camssa:e9ca23be-3e5a-4c4b-b8ca-f8cf2bc9013b a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """Although XHTML is a reformulation of HTML 4 using XML, it is not dependant of any version of the two standards. So, XHTML is independent of any technology or software.
#
# XHTML W3C reference:
# https://www.w3.org/TR/xhtml1/"""@en ;
#     cav:refersTo camssa:472b5663-c40a-4911-8172-4385540bd030 .
#
# camssa:e9d81cfd-f179-4b0b-af00-59923ba6429b a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-a2e2820561158593079cf28230b73b9b7f1cb83da49b04d2317790e20c0c706f ;
#     cav:value "100"^^xsd:int .
#
# camssa:e9e75515-190f-489a-8134-d2066b34bc28 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """OWL2 is maintained by W3C which is an international community developing open standards. _x000D_
# _x000D_
# Developer community W3C:_x000D_
# https://www.w3.org/Consortium/"""@en ;
#     cav:refersTo camssa:735d0bac-efcd-476c-90a0-9da057e04e0d .
#
# camssa:e9f290f2-e53b-47fc-a158-141bcd3ad830 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement "None"@en ;
#     cav:refersTo camssa:7b2ddb38-4dc9-4e94-932b-b4f00813497b .
#
# camssa:ea05dfec-3ea3-42f2-9ca2-0a18d26cbb4d a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """The purpose of PNG is not related with data portability. Therefore, this criterion is not applicable to this specification.
#
# PNG W3C reference:
# https://www.w3.org/TR/PNG/
#
# PNG ISO reference:
# https://www.iso.org/standard/29581.html"""@en ;
#     cav:refersTo camssa:e266f47a-325a-4c64-994b-191ad43e48ff .
#
# camssa:ea08802e-128e-4931-8c45-79a2f5343f68 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement "The purpose of WS-Security is not related to e-accessibility. Therefore, this criterion is not applicable to the specification."@en ;
#     cav:refersTo camssa:7b40f124-7de3-4dd7-82b8-3fdad1a8df5c .
#
# camssa:ea265e24-ef78-4661-90c3-5d637fc96790 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-fb2c0a4ddb03b09ecd5450c5a1d6aeed4e51c2a0387709a95a89cd850a7dd180 ;
#     cav:value "100"^^xsd:int .
#
# camssa:ea273d0a-047b-46dc-a549-3df912004725 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """Like all the IETF standards, HTTP is a free and open technical specification, built on IETF standards and licenses from the Open Web Foundation. HTTP 1.1 is therefore licensed on a royalty-free basis.
#
# See:
# https://tools.ietf.org/html/rfc3668                                                                                                                                        https://tools.ietf.org/html/rfc2616"""@en ;
#     cav:refersTo camssa:5b20fe5b-6e30-4fcb-9ff8-8f066113dcc6 .
#
# camssa:ea383cf2-152c-45ab-9d05-d7306c809f3f a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-0b122f4f42ca2089ee158a31d932d6a0332aa3a4d04acce1e2e7aa140815a0ec ;
#     cav:value "20"^^xsd:int .
#
# camssa:ea44118c-41ab-4bff-9dc7-ad28cf66ee7a a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-ec3f8a897147f530040ab94fb9bbee9fdad56e7256b2ce6fbb63cf1465315d91 ;
#     cav:value "100"^^xsd:int .
#
# camssa:ea496374-50b9-4979-bdb6-a11cd6c23b23 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """'There are many available public online channels for the exchange of help and knowledge among REST users. See the links below for such examples.
#
# Microsoft developer network reference:
# https://social.msdn.microsoft.com/Forums/es-ES/d720e383-96ca-4b8a-9d53-ad78bc51eeee/web-api-rest-c-json
#
# Opentext developer reference:
# https://forums.opentext.com/forums/developer/discussion/235439/rest-api-categories'"""@en ;
#     cav:refersTo camssa:9c685fa2-611e-4b71-95bc-7ebe72600a9c .
#
# camssa:ea4cee90-b04c-405d-900b-3852fd69778f a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement "None"@en ;
#     cav:refersTo camssa:d733d64f-d663-4ad6-9bd6-2f2b8b04388f .
#
# camssa:ea6b5f67-9289-4d2a-b91a-25d0d16bf254 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """After checking the different standard catalogues at supra-national level, the Publication Office of the European Union has listed it within EurVocabularies with all the specifications and resources produced and used by European Institutions.
#
# EU Vocabularies:
# https://op.europa.eu/en/web/eu-vocabularies
#
# Joinup post linked to the EuroVoc reosurces:
# https://joinup.ec.europa.eu/collection/eu-semantic-interoperability-catalogue/news/eurovoc-freely-available"""@en ;
#     cav:refersTo camssa:5109d53d-8aa2-4fc5-8f7a-9acd76dae8cb .
#
# camssa:ea71b9ae-6c0b-46af-84a2-565e23541076 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-22c3c5b40201f4ab2cb64a2d34b7665f8d0d1562f2a3e1a493dd3312608c7537 ;
#     cav:value "100"^^xsd:int .
#
# camssa:ea8a9d2c-8de9-4d86-be57-3cbe0e26d777 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-0e9bb259b84413d890a0fd548e40f255bb983a3add2eb7a737283f711e23d523 ;
#     cav:value "100"^^xsd:int .
#
# camssa:ea961407-e8f8-4d30-8d5e-5f1ea2fbfa80 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """Although ADMS’s purpose is not the long-term preservations, it can be used to document and store semantic assets.
#
# ADMS on Joinup:
# https://joinup.ec.europa.eu/solution/asset-description-metadata-schema-adms/about
#
# ADMS Specification W3C:
# https://www.w3.org/TR/vocab-adms/"""@en ;
#     cav:refersTo camssa:1512d9aa-cad7-4066-84eb-e5f7e5e9fe99 .
#
# camssa:ea9c56ce-cd54-499c-ae0a-93196ed1a8c5 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """ADMS supports the evolution of European Public Services by enhancing the discoverability and reuse of interoperability solutions.
#
# ADMS on Joinup:
# https://joinup.ec.europa.eu/solution/asset-description-metadata-schema-adms/about
#
# ADMS Specification W3C:
# https://www.w3.org/TR/vocab-adms/"""@en ;
#     cav:refersTo camssa:ec1a7f07-db6e-4f48-a6d5-8c1413114ba2 .
#
# camssa:eaaa2d98-126a-4a63-9f3c-d3a4ea0c20ae a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement "None"@en ;
#     cav:refersTo camssa:ff26efdd-27b1-44d1-9f30-cfae0be064bb .
#
# camssa:eab2c2c9-2f91-43e6-86ab-69c6fc5d9d8d a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """Not enough pieces of evidence have been found to answer positively or negatively to this criterion. Moreover, it seems that the purpose of the specification is not related to the delivery.
#
# OpenPM2 specification reference:
# https://op.europa.eu/en/publication-detail/-/publication/ac3e118a-cb6e-11e8-9424-01aa75ed71a1/language-en/format-PDF/source-83307127"""@en ;
#     cav:refersTo camssa:c7fca6d7-0623-4df0-9009-7e75ae7ea063 .
#
# camssa:eabda6b1-4d1b-4997-ab17-f3301a288cdc a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-a6fa642bc8eceff2b1d333dc1123748399264c028fde2fd78308f0a0209ae21b ;
#     cav:value "100"^^xsd:int .
#
# camssa:eac1d907-06fc-4787-a8d6-09b6789c9bd9 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-9420538a5a92af199b492414dd056ab7134e456f005895261b1a5b15a3f2814e ;
#     cav:value "100"^^xsd:int .
#
# camssa:eac67098-1375-492c-890e-8084f6901407 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-26aeec3cf5b3b4879325e85fcd751d0c17f62c6c3113109fb100883a553ec0af ;
#     cav:value "100"^^xsd:int .
#
# camssa:eacce3db-b386-462b-b52c-f0130681c79c a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement "None"@en ;
#     cav:refersTo camssa:9f221f27-5bf0-41f6-b10f-44a7c7a24c37 .
#
# camssa:eae67578-0354-468c-a2c6-51dc77c7ec43 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-52e41801b0db7274d934a229fee15e657273655d70d448d16706fcbe0e4f9746 ;
#     cav:value "100"^^xsd:int .
#
# camssa:eae95a5b-6f24-47fd-b97d-f38b045ad774 a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-812668363d8f0cc562041fae6c588e1555372bf0bf5c16835be996dd72070013 ;
#     cav:value "20"^^xsd:int .
#
# camssa:eafaf911-57ec-4ff3-92b0-0085eba2d319 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """The purpose of LegalDocML is to provide a format for long-term storage and access to parliamentary, legislative and judicial documents that allows search, interpretation and visualization of documents. Concequently, it can be said that the specification fosters data portability between systems and applications.
#
# LegalDocML reference:
# https://www.oasis-open.org/committees/legaldocml/charter.php"""@en ;
#     cav:refersTo camssa:36517e3e-79b6-4229-b361-ead893d0bf56 .
#
# camssa:eafb5bce-487f-44ba-be25-a4481967378d a cav:Score,
#         owl:NamedIndividual ;
#     cav:assignedTo sc:c-50ab6a29689585b917f7b2972d2c41e8c8c52723c2d58eb9b92109c938d4e825 ;
#     cav:value "100"^^xsd:int .
#
# camssa:eb03d82c-2774-4338-a23d-549967bd10d9 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """OpenPM2 has the support of the Publication Office of the European Union as a developer community.
#
# Publication Office of the European Union:
# https://op.europa.eu/en/home"""@en ;
#     cav:refersTo camssa:cf0646a4-e685-408b-a83f-ffb57d177ee2 .
#
# camssa:eb043574-1bd7-4d1a-a0d0-8946abdf3967 a cav:Statement,
#         owl:NamedIndividual ;
#     cav:judgement """At the moment of performing the assessment, the specification is not mapped with any EIRA ABBs and therefore it is not included in the ELIS v1.0.1.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
